# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
from matplotlib import pyplot as plt

# %% [markdown]
# In next step read the csv file by pandas

# %%
df=pd.read_csv('Data.csv')

# %% [markdown]
# In next step we show the head part of Dataset by using head() function

# %%
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %% [markdown]
# In the next step we show the graph of the increasing stock values which is One or decreasing stock values which is zero

# %%
pd.plotting.scatter_matrix(df,);
plt.title('Increase and decrease the values of the overall Dataset')
# Out:
# Text(0.5, 1.0, 'Increase and decrease the values of the overall Dataset')

# %%
df1=df.reset_index()['Label']

# %%
df1.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Label, dtype: int64

# %%
plt.plot(df1.head(),color="Purple")
plt.title('Graph which show the increase and decrease the Head values of Dataset', color="purple")
# Out:
# Text(0.5, 1.0, 'Graph which show the increase and decrease the Head values of Dataset')

# %% [markdown]
# In next step we make the two dataset one train dataset and other is test Dataset by date

# %%
train = df[df['Date'] < '20150101']
test = df[df['Date'] > '20141231']

# %% [markdown]
# In the next step we show the lower part of the Dataset

# %%
df.tail()
# Out:
#             Date  Label                                               Top1  \
# 4096  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 4097  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 4098  2016-06-29      1                   Explosion At Airport In Istanbul
# 4099  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 4100  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# 4096  Pope says Church should ask forgiveness from g...
# 4097  The personal details of 112,000 French police ...
# 4098  Yemeni former president: Terrorism is the offs...
# 4099  Stephen Hawking says pollution and 'stupidity'...
# 4100   IMF chief backs Athens as permanent Olympic host
#
#                                                    Top3  \
# 4096  Poland 'shocked' by xenophobic abuse of Poles ...
# 4097  S&amp;P cuts United Kingdom sovereign credit r...
# ...

# %%
plt.plot(df1.tail(),color="Purple")
plt.title('Graph which show the increase and decrease the Tail values of Dataset',color="purple")

# %% [markdown]
# In which we show the first values of the dataset through a graph

# %%
df1=test.reset_index()['Label']

# %%
df1

# %%
plt.hist(df1, label="Increase and Decrease in Stock",color="Purple")
plt.legend()
plt.ylabel("Count",color="purple")
plt.xlabel("Stock increase decrease",color="purple")
plt.title("In this graph we show the increasing and decreasing of the stock in the test Dataset",color="purple")

# %% [markdown]
# In the next step we plot a graph which shows that one values represent the increase in stock and the zero represent the decrease in stock

# %%
x = [0,1]
y = ["Decrease Stock","Increase Stock"]
fig=plt.figure()
kh=fig.add_axes([0,0,1,1])
kh.set_title('Plot Graph to show stock movement',color="purple")
plt.plot(x,y,color="0.5")

# %% [markdown]
# In the next step we plot a Height Distribution graph which show how many ones and the zeros values in the dataset

# %%
dfplot=df.plot(kind="hist", color="purple")
dfplot.set_title("Height Distribution" ,color="purple")

# %% [markdown]
# In the next step we perform the pre-processing steps for refining the dataset

# %%
# Removing punctuations
data=train.iloc[:,2:27]
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

# Renaming column names for ease of access
list1= [i for i in range(25)]
new_Index=[str(i) for i in list1]
data.columns= new_Index
data.head(5)

# %% [markdown]
# In which we conter the Headlines to the lower case

# %%
# Convertng headlines to lower case
for index in new_Index:
    data[index]=data[index].str.lower()
data.head(5)

# %%
' '.join(str(x) for x in data.iloc[1,0:25])
